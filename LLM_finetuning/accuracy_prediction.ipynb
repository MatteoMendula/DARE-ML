# %%
SERIES = [
    0.3726143538951874,
    0.19884099066257477,
    0.14179782569408417,
    0.11165603250265121,
    0.09745573997497559,
    0.08866746723651886,
    0.07731425762176514,
    0.06851502507925034,
    0.06683014333248138,
    0.060922771692276,
    0.05983350798487663,
    0.05777798593044281,
    0.045875515788793564,
    0.042474158108234406,
    0.03403465449810028,
    0.037821922451257706,
    0.028600696474313736,
    0.02670535445213318,
    0.026442598551511765,
    0.02808000147342682,
    0.025090718641877174,
    0.025433504953980446,
    0.02308717928826809,
    0.021704720333218575,
    0.021248310804367065,
    0.022494418546557426,
    0.021148111671209335,
    0.020854443311691284,
    0.021964769810438156,
    0.01848481222987175,
    0.019445953890681267,
    0.02089361473917961,
    0.01838604547083378,
    0.017789727076888084,
    0.017299901694059372,
    0.019216042011976242,
    0.016085222363471985,
    0.017387501895427704,
    0.016952257603406906,
    0.01681678369641304,
    0.017651569098234177,
    0.01747472770512104,
    0.01678854040801525,
    0.015331340953707695,
    0.017264852300286293,
    0.01717745140194893,
    0.016513746231794357,
    0.016306044533848763,
    0.0168934129178524,
    0.01672990433871746,
    0.01660902053117752,
    0.01775263622403145,
    0.014936110004782677,
    0.014688247814774513,
    0.015411768108606339,
    0.01659710519015789,
    0.01668781228363514,
    0.015433217398822308,
    0.01570960506796837,
    0.015821263194084167,
    0.014372032135725021,
    0.015289184637367725,
    0.014734550379216671,
    0.01612835004925728,
    0.013737952336668968,
    0.015007877722382545,
    0.01475231721997261,
    0.015246606431901455,
    0.014674420468509197,
    0.016246940940618515,
    0.013987613841891289,
    0.013783097267150879,
    0.01504275482147932,
    0.015023486688733101,
    0.01611332781612873,
    0.01558738760650158,
    0.014744958840310574,
    0.015201883390545845,
    0.014187280088663101,
    0.01494322158396244,
    0.014114080928266048,
    0.014783416874706745,
    0.014994008466601372,
    0.014328695833683014,
    0.012910488992929459,
    0.014667969197034836,
    0.014353831298649311,
    0.014224999584257603,
    0.013881576247513294,
    0.013228720054030418,
    0.013926131650805473,
    0.012855960987508297,
    0.013754353858530521,
    0.013903978280723095,
    0.012887323275208473,
    0.013195125386118889,
    0.013502336107194424,
    0.012272230349481106,
    0.014025953598320484,
    0.013879116624593735,
    0.013772263191640377,
    0.013582226820290089,
    0.012739851139485836,
    0.013374894857406616,
    0.013882558792829514,
    0.013304581865668297,
    0.013366776518523693,
    0.014470478519797325,
    0.012781181372702122,
    0.014343174174427986,
    0.014122762717306614,
    0.014527011662721634,
    0.013975132256746292,
    0.013714820146560669,
    0.013451802544295788,
    0.012547935359179974,
    0.013113048858940601,
    0.012500910088419914,
    0.01343892328441143,
    0.013518048450350761,
    0.012104542925953865,
    0.013217899017035961,
    0.014686975628137589,
    0.013473986648023129,
    0.013123624958097935,
    0.01407136581838131,
    0.013351434841752052,
    0.013304166495800018,
    0.013977772556245327,
    0.014024361036717892,
    0.01322922483086586,
    0.012881503440439701,
    0.013127777725458145,
    0.012672693468630314,
    0.013242199085652828,
    0.01222597248852253,
    0.013202003203332424,
    0.014231987297534943,
    0.01226680725812912,
    0.012760549783706665,
    0.012141857296228409,
    0.012326913885772228,
    0.012555667199194431,
    0.013429610058665276,
    0.012575235217809677,
    0.012911722995340824,
    0.013531262055039406,
    0.012992107309401035,
    0.012838096357882023,
    0.01311455573886633,
    0.01329568587243557,
    0.012235942296683788,
    0.012939659878611565,
    0.013389060273766518,
    0.013250667601823807,
    0.013231432996690273,
    0.012270688079297543,
    0.012987337075173855,
    0.012323801405727863,
    0.012766305357217789,
    0.012676204554736614,
    0.013037136755883694,
    0.0128964027389884,
    0.013039521872997284,
    0.0125798424705863,
    0.012636168859899044,
    0.01263855118304491,
    0.012706432491540909,
    0.013238243758678436,
    0.012219679541885853,
    0.012296267785131931,
    0.012323208153247833,
    0.012215745635330677,
    0.01320323534309864,
    0.012855958193540573,
    0.012686651200056076,
    0.012436616234481335,
    0.012424810789525509,
    0.011951171793043613,
    0.01273554190993309,
    0.01250599417835474,
    0.012354585342109203,
    0.012369208969175816,
    0.012155018746852875,
    0.012337135151028633,
    0.012415317818522453,
    0.012272131629288197,
    0.012469847686588764,
    0.012504909187555313,
]

# %%
from matplotlib import pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.arima.model import ARIMA
import time

# %%
# plot the series
plt.plot(SERIES)

# %%
scaler = StandardScaler()
scaled_series = scaler.fit_transform(np.array(SERIES).reshape(-1, 1)).flatten()

train_percentage = 0.8
train = scaled_series[:int(train_percentage * len(scaled_series))]
test = scaled_series[int(train_percentage * len(scaled_series)):]

train_features = np.array(train[:-1])
train_target = np.array(train[1:])

test_features = np.array(test[:-1])
test_target = np.array(test[1:])

# %%
class StackedEchoStateNetworkWithIP:
    def __init__(self, input_size, reservoir_sizes, output_size, spectral_radius=0.9, target_mean=0, target_std=1, lr=0.001):
        self.num_layers = len(reservoir_sizes)
        self.spectral_radius = spectral_radius
        self.target_mean = target_mean  # Target mean for activations
        self.target_std = target_std    # Target standard deviation for activations
        self.lr = lr  # Learning rate for intrinsic plasticity
        self.reservoir_sizes = reservoir_sizes
        
        # Initialize the reservoirs and their intrinsic plasticity parameters
        self.W_in = []
        self.W_res = []
        self.gains = []
        self.biases = []
        
        for i, reservoir_size in enumerate(reservoir_sizes):
            in_size = input_size if i == 0 else reservoir_sizes[i - 1]
            W_in = np.random.uniform(-1, 1, (reservoir_size, in_size))
            W_res = np.random.uniform(-1, 1, (reservoir_size, reservoir_size))
            W_res *= spectral_radius / np.max(np.abs(np.linalg.eigvals(W_res)))
            
            self.W_in.append(W_in)
            self.W_res.append(W_res)
            
            # Initialize gain and bias for each layer
            self.gains.append(np.ones(reservoir_size))
            self.biases.append(np.zeros(reservoir_size))
        
        # Output weight (connecting final reservoir to output)
        self.W_out = np.random.uniform(-1, 1, (reservoir_sizes[-1], output_size))  # Change shape to (100, 1)

    def _intrinsic_plasticity_update(self, neuron_output, layer):
        """
        Update the gain and bias of each neuron in the current layer using intrinsic plasticity.
        """
        delta_bias = self.lr * (self.target_mean - neuron_output)  # Update bias
        delta_gain = self.lr * (1 / self.gains[layer] + (neuron_output - self.target_mean) * (neuron_output - self.target_mean - self.target_std**2))
        self.biases[layer] += delta_bias  # Update bias term
        self.gains[layer] += delta_gain  # Update gain term

    def _update_reservoir(self, X, reservoir_state, layer):
        """
        Update reservoir for a given layer, applying gain and bias per neuron for intrinsic plasticity.
        """
        # Compute pre-activation (before applying gain and bias)
        pre_activation = np.dot(self.W_in[layer], X) + np.dot(self.W_res[layer], reservoir_state)
        
        # Apply gain and bias to each neuron's pre-activation
        reservoir_activation = np.tanh(self.gains[layer] * pre_activation + self.biases[layer])

        # Update gain and bias using intrinsic plasticity
        self._intrinsic_plasticity_update(reservoir_activation, layer)
        
        return reservoir_activation

    def fit(self, X_train, Y_train):
        # Initialize reservoir states for each layer
        reservoir_states = [np.zeros((X_train.shape[0], size)) for size in self.reservoir_sizes]
        reservoir_state = [np.zeros(size) for size in self.reservoir_sizes]
        
        # Loop through each time step
        for t in range(X_train.shape[0]):
            input_signal = X_train[t]
            
            # Update each reservoir layer
            for layer in range(self.num_layers):
                reservoir_state[layer] = self._update_reservoir(input_signal, reservoir_state[layer], layer)
                reservoir_states[layer][t] = reservoir_state[layer]
                
                # The input to the next layer is the output of the current one
                input_signal = reservoir_state[layer]
        
        # Train the readout layer using the final reservoir layer's states
        self.W_out = np.dot(np.linalg.pinv(reservoir_states[-1]), Y_train)

    def predict(self, X_test):
        Y_pred = np.zeros(X_test.shape)
        reservoir_state = [np.zeros(size) for size in self.reservoir_sizes]

        for t in range(X_test.shape[0]):
            input_signal = X_test[t]
            
            # Update each layer in sequence
            for layer in range(self.num_layers):
                reservoir_state[layer] = self._update_reservoir(input_signal, reservoir_state[layer], layer)
                input_signal = reservoir_state[layer]  # Pass to the next layer
            
            # Compute output for the final layer
            Y_pred[t] = np.dot(reservoir_state[-1], self.W_out).flatten()  # No need to reshape reservoir_state[-1]
        
        return Y_pred

# %%
def moving_average_prediction (series, window_size):
    predictions = []
    total_fitting_time = []
    for i in range(window_size, len(series)):
        start = time.time()
        window = series[i - window_size:i]
        total_fitting_time.append(time.time() - start)
        predictions.append(np.mean(window))
    return np.array(predictions), total_fitting_time

# %%
def ARIMA_prediction(series, window_size, p, d, q):
    predictions = []
    total_fitting_time = []
    total_inference_time = []
    for i in range(window_size, len(series)):
        window = series[i - window_size:i]
        model = ARIMA(window, order=(p, d, q))
        start = time.time()
        model_fit = model.fit()
        total_fitting_time += [time.time() - start]
        start = time.time()
        yhat = model_fit.forecast()[0]
        total_inference_time += [time.time() - start]
        predictions.append(yhat)

    return predictions, total_fitting_time, total_inference_time

# %%
reservoir_sizes = [30]
window_size = 25
esn_stacked_ip = StackedEchoStateNetworkWithIP(input_size=1, reservoir_sizes=reservoir_sizes, output_size=1)

# scaler = StandardScaler()
# train_features = scaler.fit_transform(train_features.reshape(-1, 1)).ravel()
# test_features = scaler.transform(test_features.reshape(-1, 1)).ravel()

# train_target = scaler.fit_transform(train_target.reshape(-1, 1)).ravel()
# test_target = scaler.transform(test_target.reshape(-1, 1)).ravel()

# add a dimension to the features
train_features = train_features.reshape(-1, 1)
test_features = test_features.reshape(-1, 1)

esn_stacked_ip_fitting_time = []

for _ in range(10):
    start_time = time.time()
    esn_stacked_ip.fit(train_features, train_target)
    esn_stacked_ip_fitting_time += [time.time() - start_time]

start_time = time.time()
train_predictions_stacked_ip = esn_stacked_ip.predict(train_features)
esn_stacked_ip_inference_time_train = time.time() - start_time
start_time = time.time()
test_predictions_stacked_ip = esn_stacked_ip.predict(test_features)
esn_stacked_ip_inference_time_test = time.time() - start_time

moving_average_predictions_train, moving_average_inference_time_train = moving_average_prediction(train_features, window_size)
moving_average_predictions_test, moving_average_inference_time_test = moving_average_prediction(test_features, window_size)

arima_predictions_train = []
arima_fitting_time_train = []
arima_inference_time_train = []
arima_predictions_test = []
arima_fitting_time_test = []
arima_inference_time_test = []

arima_predictions_train, arima_fitting_time_train, arima_inference_time_train = ARIMA_prediction(train_features, window_size, 5, 0, 0)
arima_predictions_test, arima_fitting_time_test, arima_inference_time_test = ARIMA_prediction(test_features, window_size, 5, 0, 0)

# scale back the predictions
train_predictions_stacked_ip = scaler.inverse_transform(train_predictions_stacked_ip.reshape(-1, 1)).ravel()
test_predictions_stacked_ip = scaler.inverse_transform(test_predictions_stacked_ip.reshape(-1, 1)).ravel()

moving_average_predictions_train = scaler.inverse_transform(moving_average_predictions_train.reshape(-1, 1)).ravel()
moving_average_predictions_test = scaler.inverse_transform(moving_average_predictions_test.reshape(-1, 1)).ravel()

arima_predictions_train = scaler.inverse_transform(np.array(arima_predictions_train).reshape(-1, 1)).ravel()
arima_predictions_test = scaler.inverse_transform(np.array(arima_predictions_test).reshape(-1, 1)).ravel()

# scale back the target
train_target = scaler.inverse_transform(train_target.reshape(-1, 1)).ravel()
test_target = scaler.inverse_transform(test_target.reshape(-1, 1)).ravel()

# loss cannot be negative, multiply by -1 if negative 
# train_predictions_stacked_ip = np.maximum(train_predictions_stacked_ip, 0)
# test_predictions_stacked_ip = np.maximum(test_predictions_stacked_ip, 0)

# moving_average_predictions_train = [x if x > 0 else -1 * x for x in moving_average_predictions_train]
# moving_average_predictions_test = [x if x > 0 else -1 * x for x in moving_average_predictions_test]

# arima_predictions_train = [x if x > 0 else -1 * x for x in arima_predictions_train]
# arima_predictions_test = [x if x > 0 else -1 * x for x in arima_predictions_test]
# Out:
# /home/matteo/anaconda3/envs/eneaFL/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/matteo/anaconda3/envs/eneaFL/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/matteo/anaconda3/envs/eneaFL/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/matteo/anaconda3/envs/eneaFL/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
# save predictions
np.save('train_predictions_stacked_ip.npy', train_predictions_stacked_ip)
np.save('test_predictions_stacked_ip.npy', test_predictions_stacked_ip)
np.save('moving_average_predictions_train.npy', moving_average_predictions_train)
np.save('moving_average_predictions_test.npy', moving_average_predictions_test)
np.save('arima_predictions_train.npy', arima_predictions_train)
np.save('arima_predictions_test.npy', arima_predictions_test)

# %%
# plot the predictions compared to the true values
plt.plot(train_target, label="Ground Truth", marker="x")
plt.plot(moving_average_predictions_train, label="Moving Average", marker="+")
plt.plot(arima_predictions_train, label="ARIMA", marker="*")
plt.plot(train_predictions_stacked_ip, label="ESN", marker="o", markersize=2)

# set y label
plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epochs")
plt.grid()

plt.title("Cross Entropy Loss Estimation over all epochs")

plt.legend()

# %%
max_index = 25

# plot the predictions compared to the true values
plt.plot(train_target[:max_index], label="Ground Truth", marker='x')
plt.plot(moving_average_predictions_train[:max_index], label="Moving Average rain", marker='+')
plt.plot(arima_predictions_train[:max_index], label="ARIMA", marker='*')
plt.plot(train_predictions_stacked_ip[:max_index], label="ESN", marker='o', markersize=2)

plt.ylabel("Cross Entropy Loss")
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.title("Cross Entropy Loss Estimation over first 25 epochs")
# Out:
# Text(0.5, 1.0, 'Cross Entropy Loss Estimation over first 25 epochs')

# %%
# shift to the right by the window size moving average and

plt.plot(test_predictions_stacked_ip, label="Test predictions stacked IP")
plt.plot(test_target, label="Test target")
plt.plot(moving_average_predictions_test, label="Moving average test")
plt.plot(arima_predictions_test, label="ARIMA test")

plt.legend()

# %%
print("ESN stacked IP fitting time:", esn_stacked_ip_fitting_time)
print("ESN stacked IP inference time train:", esn_stacked_ip_inference_time_train)
print("ESN stacked IP inference time test:", esn_stacked_ip_inference_time_test)
print("----------------")
print("Moving average inference time train:", np.mean(moving_average_inference_time_train), np.std(moving_average_inference_time_train))
print("Moving average inference time test:", np.mean(moving_average_inference_time_test), np.std(moving_average_inference_time_test))
print("----------------")
print("ARIMA fitting time train:", np.mean(arima_fitting_time_train), np.std(arima_fitting_time_train))
print("ARIMA inference time train:", np.mean(arima_inference_time_train), np.std(arima_inference_time_train))
print("ARIMA fitting time test:", np.mean(arima_fitting_time_test), np.std(arima_fitting_time_test))
print("ARIMA inference time test:", np.mean(arima_inference_time_test), np.std(arima_inference_time_test))
# Out:
# ESN stacked IP fitting time: [0.0038025379180908203, 0.0019147396087646484, 0.002270936965942383, 0.002310514450073242, 0.001983165740966797, 0.00197601318359375, 0.0018129348754882812, 0.0018453598022460938, 0.001968860626220703, 0.001977205276489258]
# ESN stacked IP inference time train: 0.001966238021850586
# ESN stacked IP inference time test: 0.0005648136138916016
# ----------------
# Moving average inference time train: 2.13623046875e-07 1.7796697304427148e-07
# Moving average inference time test: 3.178914388020833e-07 1.7770671665666816e-07
# ----------------
# ARIMA fitting time train: 0.06094167709350586 0.011426609648935507
# ARIMA inference time train: 0.0014674530029296876 0.00010486517226229913
# ARIMA fitting time test: 0.06796824932098389 0.013520169021188974
# ARIMA inference time test: 0.00152587890625 8.824982466266442e-05

# %%
# Organizing data for the boxplot
data_ms = [
    esn_stacked_ip_fitting_time,
    # esn_stacked_ip_inference_time_train,
    # esn_stacked_ip_inference_time_test,

    [x * 1000 for x in moving_average_inference_time_train],
    # [x * 1000 for x in moving_average_inference_time_test],
    [x * 1000 for x in arima_fitting_time_train],
    [x * 1000 for x in arima_inference_time_train],
    # [x * 1000 for x in arima_fitting_time_test],
    # [x * 1000 for x in arima_inference_time_test]
] 

# Labels for each dataset
labels = [
    "ESN Stacked IP Fitting Time",
    # "ESN Stacked IP Inference Time Train",
    # "ESN Stacked IP Inference Time Test",
    "Moving Avg Inference Time Train",
    # "Moving Avg Inference Time Test",
    "ARIMA Fitting Time Train",
    # "ARIMA Inference Time Train",
    "ARIMA Fitting Time Test",
    # "ARIMA Inference Time Test"
]

# Create the boxplot
plt.figure(figsize=(12, 6))
plt.boxplot(data_ms, vert=True, patch_artist=True, labels=labels)
plt.xticks(rotation=45, ha="right")

plt.gca().set_yscale("functionlog", functions=[lambda x: x * 10, lambda x: x / 10])
plt.gca().set_yticks([0.01, 0.05, 0.1, 1, 10, 30, 150])
plt.gca().set_yticklabels(["0.1", "0.2", "0.5", "1", "10", "30","150"])

plt.ylabel("Time [ms]")
plt.title("Comparison of Fitting and Inference Times across Models and Scenarios")
plt.tight_layout()

plt.show()

# %%
# Setting up the horizontal subplot layout
fig, axes = plt.subplots(1, 3, figsize=(12, 5), gridspec_kw={'width_ratios': [2, 2, 1]})
max_index = 25

# Plot 1: Full Epoch Comparison
axes[0].plot(train_target, label="Ground Truth", marker="x")
axes[0].plot(moving_average_predictions_train, label="Moving Average", marker="+")
axes[0].plot(arima_predictions_train, label="ARIMA", marker="*")
axes[0].plot(train_predictions_stacked_ip, label="ESN", marker="o", markersize=2)
axes[0].set_ylabel("Cross Entropy Loss")
axes[0].set_xlabel("Epochs")
axes[0].grid()
axes[0].legend()
axes[0].set_title("(a)")
# axes[0].set_title("Cross Entropy Loss Estimation over all epochs")

# Plot 2: First 25 Epochs Comparison
axes[1].plot(train_target[:max_index], label="Ground Truth", marker='x')
axes[1].plot(moving_average_predictions_train[:max_index], label="Moving Average", marker='+')
axes[1].plot(arima_predictions_train[:max_index], label="ARIMA", marker='*')
axes[1].plot(train_predictions_stacked_ip[:max_index], label="ESN", marker='o', markersize=2)
# axes[1].set_ylabel("Cross Entropy Loss")
axes[1].set_xlabel("Epochs")
axes[1].grid()
axes[1].legend()
axes[1].set_title("(b)")
# axes[1].set_title("Cross Entropy Loss Estimation over first 25 epochs")

# Plot 3: Boxplot of Fitting and Inference Times
data_ms = [
    esn_stacked_ip_fitting_time,
    [x * 1000 for x in moving_average_inference_time_train],
    [x * 1000 for x in arima_fitting_time_train],
    [x * 1000 for x in arima_inference_time_train]
]
labels = [
    "ESN",
    "Moving Avg",
    "ARIMA Fitting",
    "ARIMA Estimation"
]

# Creating the boxplot with a log scale for the third plot
axes[2].boxplot(data_ms, vert=True, patch_artist=True, labels=labels)
axes[2].set_yscale("log")
axes[2].set_ylabel("Time (ms)")
axes[2].set_title("(c)")
# axes[2].set_title("Fitting and Prediction Time")
axes[2].tick_params(axis='x', rotation=45)
axes[2].grid()
plt.rcParams.update({'font.size': 12})

plt.tight_layout()
plt.savefig("accuracy.pdf")
plt.show()
